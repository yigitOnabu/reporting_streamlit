# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # ADVICE COMPLETION RATE

# %%
advice_comp_rate = pd.read_csv('people/advice_completion_rate.csv')
advice_comp_rate.head()
# Out:
#                                  userId         fullName  total_given  \
# 0  22078751-34f0-4ed5-806f-78b5e36b4f35     Yiğit Ağalar            1
# 1  601d7d84-ff58-4dcc-a1e1-041f5948bb3d  egehan karaköse            3
# 2  8793280a-4391-407d-971d-fed93d99205c     Ozgur Tellal           13
# 3  59e51cd4-40d9-4856-bbb6-2d740d510df8     ozgur tellal            7
# 4  e3d2c650-ec45-40f0-83f7-05159519c2fc     Özgür Tellal            8
#
#    total_completed  completion_rate
# 0                1       100.000000
# 1                2        66.666667
# 2                6        46.153846
# 3                2        28.571429
# 4                1        12.500000

# %%
advice_comp_rate[["fullName","completion_rate"]].plot(kind="bar",x="fullName",y="completion_rate",title="Advice Completion Rate",figsize=(10,8),legend=True,fontsize=12)
# Out:
# <AxesSubplot: title={'center': 'Advice Completion Rate'}, xlabel='fullName'>

# %%
# Creating the bar chart using Plotly
fig = go.Figure(data=[
    go.Bar(name='Completion Rate', x=advice_comp_rate['fullName'], y=advice_comp_rate['completion_rate'])
])

# Update layout
fig.update_layout(
    title='Advice Completion Rate',
    xaxis=dict(title='Full Name'),
    yaxis=dict(title='Completion Rate (%)'),
    legend=dict(x=0.01, y=0.99),
    legend_title_text='Legend',
    font=dict(size=14)
)

# Show the figure
fig.show()

# %% [markdown]
# # AVERAGE QUIZ SCORE

# %%
average_quiz_score = pd.read_csv('people/average_quiz_score.csv')
average_quiz_score.head()
# Out:
#                                  userId         fullName  avg_success_score
# 0  beb72d6b-759e-4afb-87f3-9d8353416661     Alper Berber           8.666667
# 1  21f5ef89-fb47-476a-8f33-a1f69bffb0b0          Alper B           6.000000
# 2  029681d0-24e2-48de-85b8-655638abecdd  Egehan Karakose           6.000000
# 3  f987c2cc-3cab-4610-b2df-afc30e43b02c        Emin Uzer           5.000000
# 4  59e51cd4-40d9-4856-bbb6-2d740d510df8     ozgur tellal           5.000000

# %%
# Creating the bar chart using Plotly
fig = go.Figure(data=[
    go.Bar(name='Completion Rate', x=average_quiz_score['fullName'], y=average_quiz_score['avg_success_score'])
])

# Update layout
fig.update_layout(
    title='Average Quiz Score',
    xaxis=dict(title='Full Name'),
    yaxis=dict(title='Average Quiz Score'),
    legend=dict(x=0.01, y=0.99),
    legend_title_text='Legend',
    font=dict(size=14)
)

# Show the figure
fig.show()

# %% [markdown]
# #   EVENT COMPLETION RATE

# %%
event_competion_rate = pd.read_csv('people/event_completion_rate.csv')
event_competion_rate.head(10)
# Out:
#                                  userId      fullName      name  total_given  \
# 0  22078751-34f0-4ed5-806f-78b5e36b4f35  Yiğit Ağalar    Review            1
# 1  a920844e-c0a0-4073-963d-311ed32cbda5          Vorn    Review            1
# 2  c2d14093-e4c1-4d28-a9dc-9d9c3470dcf2   Umut Arısoy    Review            3
# 3  e3d2c650-ec45-40f0-83f7-05159519c2fc  Özgür Tellal  Planning            3
# 4  e3d2c650-ec45-40f0-83f7-05159519c2fc  Özgür Tellal    Review            5
# 5  8793280a-4391-407d-971d-fed93d99205c  Ozgur Tellal  Planning            3
# 6  8793280a-4391-407d-971d-fed93d99205c  Ozgur Tellal    Review           10
# 7  59e51cd4-40d9-4856-bbb6-2d740d510df8  ozgur tellal  Planning            3
# 8  59e51cd4-40d9-4856-bbb6-2d740d510df8  ozgur tellal    Review            4
# 9  f987c2cc-3cab-4610-b2df-afc30e43b02c     Emin Uzer  Planning            3
#
#    total_completed  completion_rate
# 0                1            100.0
# 1                0              0.0
# 2                0              0.0
# 3                0              0.0
# 4                1             20.0
# 5                0              0.0
# 6                6             60.0
# 7                0              0.0
# 8                2             50.0
# 9                0              0.0

# %%
import pandas as pd
import plotly.graph_objects as go

# Sample data
data = {
    "userId": [
        # Existing data
        "22078751-34f0-4ed5-806f-78b5e36b4f35", "a920844e-c0a0-4073-963d-311ed32cbda5",
        "c2d14093-e4c1-4d28-a9dc-9d9c3470dcf2", "e3d2c650-ec45-40f0-83f7-05159519c2fc",
        "e3d2c650-ec45-40f0-83f7-05159519c2fc", "8793280a-4391-407d-971d-fed93d99205c",
        "8793280a-4391-407d-971d-fed93d99205c", "59e51cd4-40d9-4856-bbb6-2d740d510df8",
        "59e51cd4-40d9-4856-bbb6-2d740d510df8", "f987c2cc-3cab-4610-b2df-afc30e43b02c",
        # New data
        "22078751-34f0-4ed5-806f-78b5e36b4f35", "a920844e-c0a0-4073-963d-311ed32cbda5",
        "e3d2c650-ec45-40f0-83f7-05159519c2fc", "8793280a-4391-407d-971d-fed93d99205c",
    ],
    "fullName": [
        # Existing data
        "Yiğit Ağalar", "Vorn", "Umut Arısoy", "Özgür Tellal", "Özgür Tellal", 
        "Ozgur Tellal", "Ozgur Tellal", "ozgur tellal", "ozgur tellal", "Emin Uzer",
        # New data
        "Yiğit Ağalar", "Vorn", "Özgür Tellal", "Ozgur Tellal",
    ],
    "name": [
        # Existing data
        "Review", "Review", "Review", "Planning", "Review",
        "Planning", "Review", "Planning", "Review", "Planning",
        # New data
        "Design", "Design", "Design", "Design",
    ],
    "total_given": [
        # Existing data
        1, 1, 3, 3, 5, 3, 10, 3, 4, 3,
        # New data
        2, 4, 3, 5,
    ],
    "total_completed": [
        # Existing data
        1, 0, 0, 0, 1, 0, 6, 0, 2, 0,
        # New data
        2, 3, 2, 4,
    ],
    "completion_rate": [
        # Existing data
        100.0, 0.0, 0.0, 0.0, 20.0, 0.0, 60.0, 0.0, 50.0, 0.0,
        # New data
        100.0, 75.0, 66.7, 80.0,
    ]
}


df = pd.DataFrame(data)

# Preparing data for radar chart
categories = df['fullName'].unique()
total_given = df.groupby('fullName')['total_given'].sum()
completion_rate = df.groupby('fullName')['total_completed'].sum()

# Creating radar chart
fig = go.Figure()

fig.add_trace(go.Scatterpolar(
    r=total_given,
    theta=categories,
    fill='toself',
    name='Total Given'
))

fig.add_trace(go.Scatterpolar(
    r=completion_rate,
    theta=categories,
    fill='toself',
    name='Completion Rate'
))

fig.update_layout(
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, max(total_given.max(), completion_rate.max())]
        )),
    title="Performance Comparison Radar Chart",
    showlegend=True
)

# Save the figure if you want to open it in a browser
# fig.write_html("radar_chart.html")

# Show the figure
# fig.show()

# %%
import pandas as pd
import plotly.graph_objects as go

# Sample data
data = {
    "userId": [
        # Existing data
        "22078751-34f0-4ed5-806f-78b5e36b4f35", "a920844e-c0a0-4073-963d-311ed32cbda5",
        "c2d14093-e4c1-4d28-a9dc-9d9c3470dcf2", "e3d2c650-ec45-40f0-83f7-05159519c2fc",
        "e3d2c650-ec45-40f0-83f7-05159519c2fc", "8793280a-4391-407d-971d-fed93d99205c",
        "8793280a-4391-407d-971d-fed93d99205c", "59e51cd4-40d9-4856-bbb6-2d740d510df8",
        "59e51cd4-40d9-4856-bbb6-2d740d510df8", "f987c2cc-3cab-4610-b2df-afc30e43b02c",
        # New data
        "22078751-34f0-4ed5-806f-78b5e36b4f35", "a920844e-c0a0-4073-963d-311ed32cbda5",
        "e3d2c650-ec45-40f0-83f7-05159519c2fc", "8793280a-4391-407d-971d-fed93d99205c",
    ],
    "fullName": [
        # Existing data
        "Yiğit Ağalar", "Vorn", "Umut Arısoy", "Özgür Tellal", "Özgür Tellal", 
        "Ozgur Tellal", "Ozgur Tellal", "ozgur tellal", "ozgur tellal", "Emin Uzer",
        # New data
        "Yiğit Ağalar", "Vorn", "Özgür Tellal", "Ozgur Tellal",
    ],
    "name": [
        # Existing data
        "Review", "Review", "Review", "Planning", "Review",
        "Planning", "Review", "Planning", "Review", "Planning",
        # New data
        "Design", "Design", "Design", "Design",
    ],
    "total_given": [
        # Existing data
        1, 1, 3, 3, 5, 3, 10, 3, 4, 3,
        # New data
        2, 4, 3, 5,
    ],
    "total_completed": [
        # Existing data
        1, 0, 0, 0, 1, 0, 6, 0, 2, 0,
        # New data
        2, 3, 2, 4,
    ],
    "completion_rate": [
        # Existing data
        100.0, 60.0, 60.0, 60.0, 60.0, 60.0, 40.0, 40.0, 60.0, 40.0,
        # New data
        100.0,100.0, 100, 80.0,
    ]
}


df = pd.DataFrame(data)

# Selecting a specific individual from the data providedÜ
selected_individual = "Özgür Tellal"

# Filtering the data for the selected individual
individual_data = df[df['fullName'] == selected_individual]

# Grouping by event type ('name') and calculating mean completion rate
grouped_data = individual_data.groupby('name').mean().reset_index()

# Creating the radar chart
fig = go.Figure()

fig.add_trace(go.Scatterpolar(
    r=grouped_data['completion_rate'],
    theta=grouped_data['name'],
    fill='toself',
    name='Completion Rate'
))

#fig.add_trace(go.Scatterpolar(
#    r=grouped_data['total_completed'],
#    theta=grouped_data['name'],
#    fill='toself',
#    name='Completed'
#))


fig.update_layout(
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 100]

        )),
        
    title=f"Performance of {selected_individual} on Different Events",
    showlegend=True,

)

# Note: Due to the execution environment limitations, the plot may not be displayed here. 
# Please run this code in your local Python environment to view the plot.
fig.show()
# Out:
# /var/folders/pj/_k55qbhj39dcrl55zbnt5z7h0000gn/T/ipykernel_78758/2937661832.py:61: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
individual_data.groupby('name').mean().reset_index()
# Out:
# /var/folders/pj/_k55qbhj39dcrl55zbnt5z7h0000gn/T/ipykernel_78758/2683905572.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#        name  total_given  total_completed  completion_rate
# 0    Design          3.0              2.0             66.7
# 1  Planning          3.0              0.0              0.0
# 2    Review          5.0              1.0             20.0

# %% [markdown]
# # TEAM COMPLETION RATE

# %%
team_competion_rate = pd.read_csv('teams/team_completion_rate.csv')
team_competion_rate.head(10)
# Out:
#            name  total_given  total_completed  completion_rate
# 0        Debegf            3                2        66.666667
# 1        Deneme            3                2        66.666667
# 2             A           13                6        46.153846
# 3         team1           13                6        46.153846
# 4         stage           13                6        46.153846
# 5  oNabu Team 3            7                2        28.571429
# 6  oNabu Team 2            7                2        28.571429
# 7    oNabu Team            7                2        28.571429
# 8       fsdgfsg            8                1        12.500000
# 9         oNabu            8                1        12.500000

# %%
# Creating the bar chart using Plotly
fig = go.Figure(data=[
    go.Bar(name='Completion Rate', x=team_competion_rate['name'], y=team_competion_rate['completion_rate'])
])

# Update layout
fig.update_layout(
    title='Advice Completion Rate',
    xaxis=dict(title='Team Name'),
    yaxis=dict(title='Completion Rate (%)'),
    legend=dict(x=0.01, y=0.99),
    legend_title_text='Legend',
    font=dict(size=14)
)

# Show the figure
fig.show()

# %% [markdown]
# # TEAM EVENT COMPLETION RATE

# %%
team_event_competion_rate = pd.read_csv('teams/team_event_completion_rate.csv')
team_event_competion_rate
# Out:
#             name    name.1  total_given  total_completed  completion_rate
# 0         asdasd  Planning            1                0         0.000000
# 1         asdasd    Review            2                0         0.000000
# 2             aa  Planning            1                0         0.000000
# 3             aa    Review            3                0         0.000000
# 4            Asd  Planning            6                0         0.000000
# 5            Asd    Review           10                1        10.000000
# 6           Shhs    Review            3                0         0.000000
# 7         Deneme    Review            3                2        66.666667
# 8        fsdgfsg  Planning            3                0         0.000000
# 9        fsdgfsg    Review            5                1        20.000000
# 10         team1  Planning            3                0         0.000000
# 11         team1    Review           10                6        60.000000
# 12  oNabu Team 3  Planning            3                0         0.000000
# 13  oNabu Team 3    Review            4                2        50.000000
# 14        Debegf    Review            3                2        66.666667
# 15           ccc  Planning            1                0         0.000000
# 16         oNabu  Planning            3                0         0.000000
# 17         oNabu    Review            5                1        20.000000
# 18        deneme  Planning            1                0         0.000000
# 19        deneme    Review            2                0         0.000000
# 20  oNabu Team 2  Planning            3                0         0.000000
# 21  oNabu Team 2    Review            4                2        50.000000
# 22         stage  Planning            3                0         0.000000
# 23         stage    Review           10                6        60.000000
# 24         dasda  Planning            4                0         0.000000
# 25         dasda    Review            2                0         0.000000
# 26             A  Planning            3                0         0.000000
# 27             A    Review           10                6        60.000000
# 28      asdadsad    Review            3                0         0.000000
# 29    oNabu Team  Planning            3                0         0.000000
# 30    oNabu Team    Review            4                2        50.000000

# %% [markdown]
# # TEAM SPRINT COMPLETION RATE

# %%
team_spri_competion_rate = pd.read_csv('teams/sprint_team_completion_rate.csv')
team_spri_competion_rate
# Out:
#             name                        name.1  no  total_given  \
# 0          team1                  PreSprinting   0            6
# 1          team1    Shine On You Crazy Diamond   8            4
# 2          team1                 Gonna Fly Now   9            4
# 3          team1           The Final Countdown  10            4
# 4          team1             Bohemian Rhapsody  11            4
# 5          team1                Pinball Wizard  12            4
# 6          stage                  PreSprinting   0            6
# 7          stage    Shine On You Crazy Diamond   8            4
# 8          stage                 Gonna Fly Now   9            4
# 9          stage           The Final Countdown  10            4
# 10         stage             Bohemian Rhapsody  11            4
# 11         stage                Pinball Wizard  12            4
# 12          Shhs               Keep On Running   5            4
# 13          Shhs                        Smooth   7            2
# 14  oNabu Team 3                  PreSprinting   0            6
# 15  oNabu Team 3  Let's Get It Started (Agile)   2            4
# 16  oNabu Team 3          I Wanna Rock (Scrum)   3            4
# 17  oNabu Team 2                  PreSprinting   0            6
# 18  oNabu Team 2  Let's Get It Started (Agile)   2            4
# 19  oNabu Team 2          I Wanna Rock (Scrum)   3            4
# 20    oNabu Team                  PreSprinting   0            6
# 21    oNabu Team  Let's Get It Started (Agile)   2            4
# 22    oNabu Team          I Wanna Rock (Scrum)   3            4
# 23         oNabu                  PreSprinting   0            4
# 24         oNabu          Start Me Up (Change)   1            4
# 25         oNabu                     Sprint #1   1            2
# 26         oNabu  Let's Get It Started (Agile)   2            6
# 27       fsdgfsg                  PreSprinting   0            6
# 28       fsdgfsg          Start Me Up (Change)   1            4
# 29       fsdgfsg  Let's Get It Started (Agile)   2            2
# 30       fsdgfsg          I Wanna Rock (Scrum)   3            4
# 31        Deneme          Start Me Up (Change)   1            4
# 32        Deneme  Let's Get It Started (Agile)   2            2
# 33        deneme                  PreSprinting   0            2
# 34        deneme          Start Me Up (Change)   1            4
# 35        Debegf          Start Me Up (Change)   1            4
# 36        Debegf  Let's Get It Started (Agile)   2            2
# 37         dasda                  PreSprinting   0            4
# 38         dasda                     Sprint #1   1            6
# 39         dasda           The Final Countdown  10            2
# 40           ccc                  PreSprinting   0            2
# 41        asdasd                  PreSprinting   0            2
# 42        asdasd          Start Me Up (Change)   1            4
# 43      asdadsad               Keep On Running   5            4
# 44      asdadsad                        Smooth   7            2
# 45           Asd                  PreSprinting   0            6
# 46           Asd          Start Me Up (Change)   1            4
# 47           Asd                     Sprint #1   1           18
# 48           Asd                     Sprint #2   2            2
# 49           Asd                     Sprint #3   3            2
# 50            aa                  PreSprinting   0            2
# 51            aa          Start Me Up (Change)   1            4
# 52            aa                     Sprint #1   1            2
# 53             A                  PreSprinting   0            6
# 54             A    Shine On You Crazy Diamond   8            4
# 55             A                 Gonna Fly Now   9            4
# 56             A           The Final Countdown  10            4
# 57             A             Bohemian Rhapsody  11            4
# 58             A                Pinball Wizard  12            4
#
#     total_completed  completion_rate
# 0                 0              0.0
# 1                 2             50.0
# 2                 4            100.0
# 3                 2             50.0
# 4                 2             50.0
# 5                 2             50.0
# 6                 0              0.0
# 7                 2             50.0
# 8                 4            100.0
# 9                 2             50.0
# 10                2             50.0
# 11                2             50.0
# 12                0              0.0
# 13                0              0.0
# 14                0              0.0
# 15                2             50.0
# 16                2             50.0
# 17                0              0.0
# 18                2             50.0
# 19                2             50.0
# 20                0              0.0
# 21                2             50.0
# 22                2             50.0
# 23                0              0.0
# 24                2             50.0
# 25                0              0.0
# 26                0              0.0
# 27                0              0.0
# 28                2             50.0
# 29                0              0.0
# 30                0              0.0
# 31                4            100.0
# 32                0              0.0
# 33                0              0.0
# 34                0              0.0
# 35                4            100.0
# 36                0              0.0
# 37                0              0.0
# 38                0              0.0
# 39                0              0.0
# 40                0              0.0
# 41                0              0.0
# 42                0              0.0
# 43                0              0.0
# 44                0              0.0
# 45                0              0.0
# 46                2             50.0
# 47                0              0.0
# 48                0              0.0
# 49                0              0.0
# 50                0              0.0
# 51                0              0.0
# 52                0              0.0
# 53                0              0.0
# 54                2             50.0
# 55                4            100.0
# 56                2             50.0
# 57                2             50.0
# 58                2             50.0

# %%
import plotly.express as px
import pandas as pd

# Sample data


# Filter data for "oNabu"
filtered_data = team_spri_competion_rate[team_spri_competion_rate["name"] == "team1"]

# Create a Plotly line chart
fig = px.line(filtered_data, x="name.1", y="completion_rate", title="Team Completion Rate", markers=True)

# Update layout with width and height
fig.update_layout(
    xaxis_title="Sprint",
    yaxis_title="Completion Rate (%)",
    legend_title="Legend",
    font=dict(size=12),
    width=1000,  # Width in pixels
    height=800   # Height in pixels
)

# Show the figure
fig.show()
